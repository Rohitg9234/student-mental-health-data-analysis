# %% [markdown]
# **A STATISTICAL RESEARCH ON THE EFFECTS OF MENTAL HEALTH ON STUDENTS’ CGPA******

# %%
#import numpy as np # linear algebra
import pandas as pd # data processing
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# # Reading the Dataset

# %%
df = pd.read_csv('/content/Student Mental health (Responses) - Form Responses .csv')

# %%
df.head()
# Out:
#             Timestamp Choose your gender What is your course?  \
# 0  11/1/2023 13:54:08               Male                 MECH
# 1  11/1/2023 20:10:40               Male                 MECH
# 2  11/1/2023 20:42:10             Female                 MECH
# 3  11/1/2023 20:42:46               Male                  ECE
# 4  11/1/2023 20:43:35             Female                 MECH
#
#   Select the program? Your current year of Study What is your CGPA?  \
# 0               Btech                   3rd Year          Range 7-8
# 1               Btech                   3rd Year          Range 7-8
# 2               Btech                   3rd Year          Range 8-9
# 3               Btech                   1st Year         Range 9-10
# 4               Btech                   3rd Year          Range 6-7
#
#   Have you satisfied with branch you got?  \
# 0                                     Yes
# 1                                     Yes
# 2                                     Yes
# ...

# %%
df.shape
# Out:
# (184, 12)

# %%
df.dtypes
# Out:
# Timestamp                                       object
# Choose your gender                              object
# What is your course?                            object
# Select the program?                             object
# Your current year of Study                      object
# What is your CGPA?                              object
# Have you satisfied with branch you got?         object
# Do you feel tension with 85% attendance?        object
# Do you have Depression?                         object
# Do you have Anxiety?                            object
# Do you have Panic attack?                       object
# Did you seek any specialist for a treatment?    object
# dtype: object

# %%
df.nunique()
# Out:
# Timestamp                                       82
# Choose your gender                               2
# What is your course?                             5
# Select the program?                              3
# Your current year of Study                       5
# What is your CGPA?                               5
# Have you satisfied with branch you got?          2
# Do you feel tension with 85% attendance?         2
# Do you have Depression?                          2
# Do you have Anxiety?                             2
# Do you have Panic attack?                        2
# Did you seek any specialist for a treatment?     2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Timestamp                                       1
# Choose your gender                              1
# What is your course?                            1
# Select the program?                             1
# Your current year of Study                      1
# What is your CGPA?                              1
# Have you satisfied with branch you got?         1
# Do you feel tension with 85% attendance?        1
# Do you have Depression?                         1
# Do you have Anxiety?                            1
# Do you have Panic attack?                       1
# Did you seek any specialist for a treatment?    1
# dtype: int64

# %%
df = df.dropna(how='any',axis=0)

# %%
df.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# What is your course?                            0
# Select the program?                             0
# Your current year of Study                      0
# What is your CGPA?                              0
# Have you satisfied with branch you got?         0
# Do you feel tension with 85% attendance?        0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
df['gender']=df['Choose your gender']
plt.figure(figsize=(12,6))
plt.title("gender distribution")
g = plt.pie(df.gender.value_counts(), explode=(0.025,0.025), labels=df.gender.value_counts().index, colors=['skyblue','navajowhite'],autopct='%1.1f%%', startangle=180);
plt.legend()
plt.show()

# %% [markdown]
# The majority of Gform submissions are from males (60.1%), with females making up the remaining 39.9%.

# %%
data=pd.DataFrame()

data['B']=df['Have you satisfied with branch you got?']
plt.figure(figsize=(12,6))
plt.title("Satisfied with branch")
g = plt.pie(data.B.value_counts(), explode=(0.025,0.025), labels=data.B.value_counts().index, colors=['skyblue','navajowhite'],autopct='%1.1f%%', startangle=180);
plt.legend()
plt.show()

# %% [markdown]
# This pie chart shows that 75.4% of students are satisfied with the branch they got, while 24.6% of students are not satisfied.

# %%
plt.figure(figsize=(10,8))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Do you have Depression?", hue="Do you feel tension with 85% attendance?", data=df)
plt.title("Depression by attendence")
plt.xlabel("Depression")
plt.show()

# %% [markdown]
# Based on this statistical bar graph, we can infer that 85% attendance is not the cause of student depression

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Do you have Anxiety?", hue="Do you feel tension with 85% attendance?", data=df)
plt.title("Anxiety by attendence")
plt.xlabel("Anxiety")
plt.show()

# %% [markdown]
# This statistical bar graph shows that attendance is a major factor in student anxiety

# %%
df['attenedence']=df['Do you feel tension with 85% attendance?']
plt.figure(figsize=(12,6))
plt.title("Student feel tension with 85% attendance")
g = plt.pie(df.attenedence.value_counts(),explode=(0.025,0.025), labels=df.attenedence.value_counts().index, colors=['skyblue','navajowhite'],autopct='%1.1f%%', startangle=180);
plt.legend()
plt.show()

# %% [markdown]
# Over two-thirds of students **(64.5%)** reported feeling tension with **85% attendance**, while less than one-third **(35.5%)** did not.

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=df['Your current year of Study'],hue=df['Choose your gender'])
plt.title("Students studying in particular year");

# %% [markdown]
# **Year wise Gender distribution of student**
#
# Only in 5th year number of male is greater than female
#
# In first year,Ratio.of males are greater than female

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=df['What is your CGPA?'],hue=df['Do you have Depression?'])
plt.title("Depression by CGPA")
plt.ylabel('CGPA')
plt.show()

# %% [markdown]
# Student who have **CGPA 8-9** are less likely to have depression.

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Do you have Anxiety?", hue="Choose your gender", data=df)
plt.title("Anxiety by Gender")
plt.ylabel("Anxiety")
plt.show()

# %% [markdown]
# **In this graph ,**
#
# we can conclude that No. of male has more anxiety compare to female

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Do you have Depression?", hue="Your current year of Study", data=df)
plt.title("Depression by year of Study")
plt.ylabel("Depression")
plt.show()

# %% [markdown]
# **Based on the data**, first-year students experience a higher level of depression, while third-year students are the most likely to deny or be in denial about experiencing depression.

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Do you have Anxiety?", hue="Your current year of Study", data=df)
plt.title("Anxiety by study year")
plt.xlabel("Anxiety")
plt.show()

# %%
df['Your current year of Study'].unique

# %% [markdown]
# The number of students of 1st who openly acknowledge experiencing anxiety is higher, with the most significant denial coming from third-year students. **However, it's important to note that this may not accurately reflect the situation, as many individuals may not even be aware of their own anxiety.**

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Do you have Depression?", hue="Choose your gender", data=df)
plt.title("Depression by gender")
plt.xlabel("Depression")
plt.show()

# %% [markdown]
# Analyzing the data is somewhat challenging because it primarily consists of information about males. However, if we consider the gender ratio, it appears that males have a higher likelihood of experiencing depression compared to males.

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Do you have Panic attack?", hue="What is your CGPA?", data=df)
plt.title("Panic attack by CGPA")
plt.xlabel("Panic attack")
plt.show()

# %% [markdown]
# According to this data,
# The student whose has **CGPA around 7-8** has has most probably panic attack and the least group getting panic attack are **range 8-9**

# %% [markdown]
# # **MODELLING**

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Choose your gender', 'What is your course?',
#        'Select the program?', 'Your current year of Study',
#        'What is your CGPA?', 'Have you satisfied with branch you got?',
#        'Do you feel tension with 85% attendance?', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?', 'gender',
#        'attenedence'],
#       dtype='object')

# %% [markdown]
# ## Data Transformation

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the data
df['Choose your gender'] = label_encoder.fit_transform(df['Choose your gender'])
df['What is your course?'] = label_encoder.fit_transform(df['What is your course?'])
df['What is your CGPA?'] = label_encoder.fit_transform(df['What is your CGPA?'])
df['Have you satisfied with branch you got?'] = label_encoder.fit_transform(df['Have you satisfied with branch you got?'])
df['Do you feel tension with 85% attendance?'] = label_encoder.fit_transform(df['Do you feel tension with 85% attendance?'])
df['Do you have Depression?'] = label_encoder.fit_transform(df['Do you have Depression?'])
df['Do you have Panic attack?'] = label_encoder.fit_transform(df['Do you have Panic attack?'])
df['Your current year of Study'] = label_encoder.fit_transform(df['Your current year of Study'])
df['Select the program?'] = label_encoder.fit_transform(df['Select the program?'])
df['Do you have Anxiety?'] = label_encoder.fit_transform(df['Do you have Anxiety?'])
df['Did you seek any specialist for a treatment?'] = label_encoder.fit_transform(df['Did you seek any specialist for a treatment?'])
# Print the encoded data

df = df.drop('gender', axis=1)
df = df.drop('Timestamp', axis=1)
df = df.drop('attenedence', axis=1)
print(df.dtypes)
# Out:
# Choose your gender                              int64
# What is your course?                            int64
# Select the program?                             int64
# Your current year of Study                      int64
# What is your CGPA?                              int64
# Have you satisfied with branch you got?         int64
# Do you feel tension with 85% attendance?        int64
# Do you have Depression?                         int64
# Do you have Anxiety?                            int64
# Do you have Panic attack?                       int64
# Did you seek any specialist for a treatment?    int64
# dtype: object

# %% [markdown]
# ## 1.Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X=df.drop(columns=['Do you have Depression?'])
Y= df['Do you have Depression?']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4)

model=DecisionTreeClassifier()
model.fit(X_train, Y_train)
prediction=model.predict( X_test)

score=accuracy_score(Y_test, prediction)

score
# Out:
# 0.527027027027027

# %% [markdown]
# ## 2.Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Create and train the Logistic Regression model
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train, Y_train)



# Make predictions on new data

predictions = logistic_reg.predict(X_test)

# You can check the accuracy of predictions by comparing them to the actual values

accuracy = accuracy_score(Y_test, predictions)
print(accuracy)
# Out:
# 0.6351351351351351

# %% [markdown]
# ## 3.KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier


# Create and train the KNN model
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(X_train, Y_train)



# Make predictions on new data

predictions = knn.predict(X_test)

# You can check the accuracy of predictions by comparing them to the actual values

accuracy = accuracy_score(Y_test, predictions)
print(accuracy)
# Out:
# 0.527027027027027

# %% [markdown]
# We have conducted three different types of modeling, namely Decision Tree Classifier, Logistic Regression, and KNeighbors Classifier.
#
# The accuracy results we obtained are as follows: Decision Tree Classifier achieved  accuracy, Logistic Regression achieved  accuracy, and KNeighbors Classifier achieved  accuracy.
#
# As the Logistic Regression model exhibited the highest accuracy  among the three, we've opted to utilize this particular model.

# %% [markdown]
# ###Checking the value of n_neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier


# Create and train the KNN model
for i in range(2,10):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train, Y_train)




  # Make predictions on new data

  predictions = knn.predict(X_test)

  # You can check the accuracy of predictions by comparing them to the actual values

  accuracy = accuracy_score(Y_test, predictions)
  print(accuracy)
# Out:
# 0.5675675675675675
# 0.527027027027027
# 0.5405405405405406
# 0.5540540540540541
# 0.5675675675675675
# 0.6081081081081081
# 0.527027027027027
# 0.5135135135135135

# %% [markdown]
# # Predicting on user input

# %%
data1=pd.DataFrame()
a=int(input("Choose your gender \n write 1 for male and 0 for female \n"))
data1['Choose your gender']=a

b=int(input("Choose the option number\n0.CSE\n1.CSE-AI\n2.ECE \n3.MECH\n4.SM\n"))
data1['What is your course?']=b

c=int(input("Choose the option number\nwrite only option number\n0.Btech\n1.Mtech\n2.Phd\n"))
data1['Select the program?']=c

d=int(input("Choose the option number\n0.1st Year\n1.2nd Year\n2.3rd Year\n3.4th Year\n4.5th year\n"))
data1['Your current year of Study']=d

e=int(input("Choose the option number\n0.Below 6\n1.Range 7-8\n2.Range 8-9\n3.Range 8-9\n4.Range 9-10\n"))
data1['What is your CGPA?']=e

f=int(input("Have you satisfied with branch you got?\nwrite 1 for NO and 0 for YES 1\n"))
data1['Have you satisfied with branch you got?']=f

g=int(input("Do you feel tension with 85% attendance?\nwrite 1 for NO and 0 for YES 1\n"))
data1['Do you feel tension with 85% attendance?']=g



h=int(input("Do you have Anxiety??\nwrite 1 for NO and 0 for YES 1\n"))
data1['Do you have Anxiety?']=h

i=int(input("Do you have Panic attack??\nwrite 1 for NO and 0 for YES 1\n"))
data1['Do you have Panic attack?']=i

j=int(input("Did you seek any specialist for a treatment?\nwrite 1 for NO and 0 for YES 1\n"))
data1['Did you seek any specialist for a treatment?']=j



new_data=[{'Choose your gender': a, 'What is your course?': b,'Select the program?':c,'Your current year of Study': d, 'What is your CGPA?': e,'Have you satisfied with branch you got?':f,'Do you feel tension with 85% attendance?': g, 'Do you have Anxiety?': h,'Do you have Panic attack?':i, 'Did you seek any specialist for a treatment?':j}]
data1 = data1.append(new_data, ignore_index=True)

predictions = knn.predict(data1)
if(predictions==1):
  text="Student is not in depression"

else:
  text="Most probably Student is in depression"


#to write in bold
bold = "\033[1m"
reset = "\033[0m"
big_text = "\033[8m"

# Text to be printed


# Print in bold and bigger size
print(bold + big_text + text + reset)
# Out:
# Choose your gender
#  write 1 for male and 0 for female
# 1
# Choose the option number
# 0.CSE
# 1.CSE-AI
# 2.ECE
# 3.MECH
# 4.SM
# 1
# Choose the option number
# write only option number
# 0.Btech
# 1.Mtech
# 2.Phd
# 0
# Choose the option number
# 0.1st Year
# 1.2nd Year
# 2.3rd Year
# 3.4th Year
# 4.5th year
# 3
# Choose the option number
# 0.Below 6
# 1.Range 7-8
# 2.Range 8-9
# 3.Range 8-9
# 4.Range 9-10
# 1
# Have you satisfied with branch you got?
# write 1 for NO and 0 for YES 1
# 1
# Do you feel tension with 85% attendance?
# write 1 for NO and 0 for YES 1
# 1
# Do you have Anxiety??
# write 1 for NO and 0 for YES 1
# 1
# Do you have Panic attack??
# write 1 for NO and 0 for YES 1
# 1
# Did you seek any specialist for a treatment?
# write 1 for NO and 0 for YES 1
# 1
# Student is not in depression
# <ipython-input-321-60fa347b0cf6>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
1
